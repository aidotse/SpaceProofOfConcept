# %% [markdown]
# # Space Proof Of Concept - data demo

# %%
import matplotlib.pyplot as plt
from pathlib import Path
import xarray as xr

# %% [markdown]
# The repo comes with a few small datasets, patches of Sentinal-2 images. One time frame of 2000x2000 and 1000x1000 pixels.

# %%
path_src = Path("img")

patches_20x20_ex = [
    #"agriculture_1_2019_i0.nc",
    #"archipelago_2020_i12.nc",
    #"gothenburg_2020_i12.nc",
    #"gotland_2020_i1.nc",
    #"kebnekaise_2019_i117.nc",
    #"oresund_2019_i0.nc",
    #"rural_1_2020_i12.nc",
    #"rural_2_2020_i0.nc",
    "vellinge_2019_i0.nc",
]
patches_10x10_ex = [
    #"agriculture_1_2019_i0_500_500_1000_1000.nc",
    #"archipelago_2020_i12_500_700_1000_1000.nc",
    #"gothenburg_2020_i12_500_500_1000_1000.nc",
    #"gotland_2020_i1_1000_0_1000_1000.nc",
    #"kebnekaise_2019_i117_500_500_1000_1000.nc",
    #"oresund_2019_i0_500_500_1000_1000.nc",
    #"rural_1_2020_i12_500_500_1000_1000.nc",
    #"rural_2_2020_i0_500_500_1000_1000.nc",
    "vellinge_2019_i0_800_700_1000_1000.nc",
]

# %% [markdown]
# Load path no i.

# %%
i = 0  # patch no
path_20x20_i = path_src.joinpath(patches_20x20_ex[i])
path_10x10_i = path_src.joinpath(patches_10x10_ex[i])
ds_20x20 = xr.open_dataset(path_20x20_i, chunks={"time": 10})
ds_10x10 = xr.open_dataset(path_10x10_i, chunks={"time": 10})
#print(ds_20x20)
#print(ds_10x10)

# %% [markdown]
# # Plot True color RGB

# %%
da_rgb_20x20 = ds_20x20[["B04_10m", "B03_10m", "B02_10m"]].to_array()
da_rgb_20x20.plot.imshow(size=10, vmin=0, vmax=2500)
plt.axis("square")
# Out:
# (355590.0, 375590.0, 6129450.0, 6149450.0)

# %%
da_rgb_10x10 = ds_10x10[["B04_10m", "B03_10m", "B02_10m"]].to_array()
da_rgb_10x10.plot.imshow(size=10, vmin=0, vmax=2500)
plt.axis("square")
# Out:
# (357590.0, 367590.0, 6136450.0, 6146450.0)

# %% [markdown]
# # Plot True color RGB
